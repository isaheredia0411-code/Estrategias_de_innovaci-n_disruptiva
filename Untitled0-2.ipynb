# %% [markdown]
# # Introducción a la Innovación Disruptiva
#
# ## Creación de bases de datos
#
# ![Image](https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExeWhwaWZ2eHJ5OWFoNnNscXQ3cWZpN3MyNzV4ZHlmY3VvcmE0aGhmMiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/sJWNLTclcvVmw/giphy.gif)

# %%
top_startups = {
  "top_startups_2024": [
    {
      "name": "Perplexity AI",
      "category": "Conversational search / AI",
      "founded": 2022,
      "highlight": "Rápido crecimiento en búsquedas y ya valorada en varios miles de millones",
      "source": ["Exploding Topics", "CodeConcepts"]
    },
    {
      "name": "Writer",
      "category": "AI marketing / customer experience",
      "founded": None,
      "highlight": "Levantó $200M en Serie C y valuation ~1.9 mil M",
      "source": ["Blumberg Capital"]
    },
    {
      "name": "ElevenLabs",
      "category": "Text‑to‑speech AI",
      "founded": None,
      "highlight": "Entró al club unicornio con valuación ~$1 mil M en enero",
      "source": ["TechCrunch"]
    },
    {
      "name": "EvenUp",
      "category": "Legaltech / AI",
      "founded": None,
      "highlight": "Valorada en ~$1 mil M tras ronda de $135 M",
      "source": ["TechCrunch"]
    },
    {
      "name": "Codeium",
      "category": "AI code acceleration",
      "founded": None,
      "highlight": "Listado Forbes como con potencial de unicornio",
      "source": ["LinkedIn Forbes list"]
    },
    {
      "name": "LangChain",
      "category": "Framework para apps LLM",
      "founded": None,
      "highlight": "Potencial unicornio según Forbes",
      "source": ["LinkedIn Forbes list"]
    },
    {
      "name": "Scribe",
      "category": "Documentación workflow AI",
      "founded": None,
      "highlight": "Forbes top 25 futuros unicornios",
      "source": ["LinkedIn Forbes list"]
    },
    {
      "name": "Clay",
      "category": "AI assistant CRM",
      "founded": None,
      "highlight": "Listed por Forbes como startup con mayor potencial",
      "source": ["LinkedIn Forbes list"]
    },
    {
      "name": "Cortex",
      "category": "Software quality / deployment AI",
      "founded": None,
      "highlight": "Incluida por Forbes entre las 25 más prometedoras",
      "source": ["LinkedIn Forbes list"]
    },
    {
      "name": "Cohere Health",
      "category": "Healthcare AI",
      "founded": None,
      "highlight": "Destacado en lista de ‘top tech startups of 2024’",
      "source": ["SunriseGeek"]
    }
  ]
}

# %%
EID_701 = {"Mago":[30, "soltero", "Said",1.70],
        "Sam":[21, "soltera", "Blee", 1.67],
        "Luis": [20, "soltero", "Angie", 1.65]}

# %%
EID_701.keys()
# Out:
# dict_keys(['Mago', 'Sam', 'Luis'])

# %%
EID_701.values()
# Out:
# dict_values([[30, 'soltero', 'Said', 1.7], [21, 'soltera', 'Blee', 1.67], [20, 'soltero', 'Angie', 1.65]])

# %%
import pandas as pd

DF_701 = pd.DataFrame(EID_701, index = ["edad", "estado civil", "pareja", "altura"])

# %%
DF_701
# Out:
#       Mago      Sam     Luis
# 0       30       21       20
# 1  soltero  soltera  soltero
# 2     Said     Blee    Angie
# 3      1.7     1.67     1.65

# %%
# ¿Cuáles son los datos de Sam?
DF_701["Sam"]
# Out:
# 0         21
# 1    soltera
# 2       Blee
# 3       1.67
# Name: Sam, dtype: object

# %%
# ¿Cuáles son los datos de Sam?
DF_701["Sam"][0]
# Out:
# 21

# %% [markdown]
# # Bases de datos

# %%
estudiantes = {"Sam": [3, 4, 5.9, 8, 3.3],
               "Angel": [-1.5, 0, 2, 5, 10],
               "Rangel": [7.7, 8.0, 8.2, 9, 9],
               "Zarate": [0, 9, 8, 3.5, 0],
               "Ricardo":[3, 6.2, 7, 2, 8]}

# %%
import pandas as pd

tablita = pd.DataFrame(estudiantes)
tablita
# Out:
#    Sam  Angel  Rangel  Zarate  Ricardo
# 0  3.0   -1.5     7.7     0.0      3.0
# 1  4.0    0.0     8.0     9.0      6.2
# 2  5.9    2.0     8.2     8.0      7.0
# 3  8.0    5.0     9.0     3.5      2.0
# 4  3.3   10.0     9.0     0.0      8.0

# %%
tablita.describe()
# Out:
#             Sam      Angel    Rangel   Zarate   Ricardo
# count  5.000000   5.000000  5.000000  5.00000  5.000000
# mean   4.840000   3.100000  8.380000  4.10000  5.240000
# std    2.095948   4.560702  0.593296  4.27785  2.605379
# min    3.000000  -1.500000  7.700000  0.00000  2.000000
# 25%    3.300000   0.000000  8.000000  0.00000  3.000000
# 50%    4.000000   2.000000  8.200000  3.50000  6.200000
# 75%    5.900000   5.000000  9.000000  8.00000  7.000000
# max    8.000000  10.000000  9.000000  9.00000  8.000000
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
